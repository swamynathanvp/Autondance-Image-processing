# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 10.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO
model=YOLO("/content/drive/MyDrive/YOLO/weights/yolov8x.pt")

# %%
model.train(data = "/content/drive/MyDrive/YOLO/data.yaml" , epochs=45 , batch=16)
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model=YOLO("/content/runs/detect/train/weights/best.pt")
results=model("/content/drive/MyDrive/data/image", save= True , classes=0, hide_labels= True , hide_conf=True)
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_conf' instead.
#
# image 1/12 /content/drive/MyDrive/data/image/IMG-20231017-WA0002.jpg: 480x640 21 persons, 58.3ms
# image 2/12 /content/drive/MyDrive/data/image/IMG-20231017-WA0003.jpg: 480x640 22 persons, 55.2ms
# image 3/12 /content/drive/MyDrive/data/image/IMG-20231017-WA0004.jpg: 480x640 20 persons, 44.3ms
# image 4/12 /content/drive/MyDrive/data/image/IMG-20231017-WA0005.jpg: 480x640 22 persons, 43.3ms
# image 5/12 /content/drive/MyDrive/data/image/IMG-20231017-WA0006.jpg: 480x640 24 persons, 41.7ms
# image 6/12 /content/drive/MyDrive/data/image/IMG-20231017-WA0007.jpg: 480x640 24 persons, 36.3ms
# image 7/12 /content/drive/MyDrive/data/image/IMG-20231017-WA0008.jpg: 480x640 24 persons, 36.2ms
# ...
